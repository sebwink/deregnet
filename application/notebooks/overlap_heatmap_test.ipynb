# %%
import sys

# %%
sys.path.append('..')

# %%
from compare_subgraphs import node_intersection_count_matrix
import seaborn as sns
import numpy as np
import igraph as ig

% matplotlib inline

# %%
M = node_intersection_count_matrix('../mode2/lihc/')
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))

# %%
M
# Out:
# array([[ 10.,   1.,   0., ...,   1.,   0.,   1.],
#        [  1.,  11.,   0., ...,   2.,   0.,   2.],
#        [  0.,   0.,  11., ...,   0.,   0.,   0.],
#        ...,
#        [  1.,   2.,   0., ...,  10.,   1.,   2.],
#        [  0.,   0.,   0., ...,   1.,  11.,   0.],
#        [  1.,   2.,   0., ...,   2.,   0.,  10.]])

# %%
M.shape
# Out:
# (297, 297)

# %%
hm = sns.clustermap(M)

# %%
np.max(M + np.diag(len(M)*[-100]))
# Out:
# 25.0

# %%
from compare_subgraphs import shortest_path_value_matrix

# %%
graph = ig.Graph.Read_GraphML('../graphs/kegg_hsa_paper.graphml')

# %%
Stest = shortest_path_value_matrix('../mode2/lihc/', graph, mode=ig.IN, subset=['AAW0', 'AAW1', 'AAW3'])
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))

# %%
Stest
# Out:
# array([[ 1.835     ,         inf,  2.12083333],
#        [        inf,         inf,         inf],
#        [ 2.12083333,         inf,  1.53472222]])

# %%
S = shortest_path_value_matrix('../mode2/lihc/', graph, mode=ig.IN)
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))

# %%
S
# Out:
# array([[        inf,  1.59545455,         inf, ...,  1.385     ,
#          1.325     ,  1.555     ],
#        [ 1.59545455,         inf,         inf, ...,         inf,
#                 inf,         inf],
#        [        inf,         inf,         inf, ...,         inf,
#                 inf,         inf],
#        ...,
#        [ 1.385     ,         inf,         inf, ...,         inf,
#                 inf,         inf],
#        [ 1.325     ,         inf,         inf, ...,         inf,
#                 inf,         inf],
#        [ 1.555     ,         inf,         inf, ...,         inf,
#                 inf,         inf]])

# %%
S[S==np.inf] = 5

# %%
np.max(S)
# Out:
# 5.0

# %%
hm = sns.clustermap(S, cmap='Blues_r')

# %%
Sout = shortest_path_value_matrix('../mode2/lihc/', graph, mode=ig.OUT)
Sout[Sout==np.inf] = 5
hm = sns.clustermap(Sout, cmap='Blues_r')
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))

# %%
S = shortest_path_value_matrix('../mode2/lihc/', graph, mode=ig.ALL)
S[S==np.inf] = 5
hm = sns.clustermap(S, cmap='Blues_r')
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))

# %%
S = shortest_path_value_matrix('../mode2/lihc/', graph, mode=ig.ALL, strategy='min')
S[S==np.inf] = 5
hm = sns.clustermap(S, cmap='Blues_r')
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))

# %%
S = shortest_path_value_matrix('../mode2/lihc/', graph, mode=ig.ALL, strategy='max')
S[S==np.inf] = 5
hm = sns.clustermap(S, cmap='Blues')
# Out:
# ../compare_subgraphs.py:8: RuntimeWarning: Could not add vertex ids, there is already an 'id' vertex attribute at foreign-graphml.c:443
#   graphs.append(ig.Graph.Read_GraphML(os.path.join(root, patient_id, 'optimal.graphml')))
